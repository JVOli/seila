# %% [markdown]
# <a href="https://colab.research.google.com/github/JVOli/seila/blob/main/Automa%C3%A7%C3%A3o_Centro_de_Custo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This code recive n excel files of Conta Azul and treat them, spliting all diferents cost centers into new lines when needed
#Imports
import pandas as pd
from google.colab import files

#Here you may upload as many files as you wish
upload = files.upload()
Arquivos = list(upload.keys())

def Tratar_dados(Arquivo:str):
  """This function its called for every uploaded file processing them and saving them in a new excel file
     Args:
       Arquivo: str, name of wished file"""
  def valor_corrigido(coluna):
    """This function ajust a monatary column spliting the values proportionly base on the center of cost and original price
       Args:
         coluna: str, name of wished collumn
    """
    row.loc[i, coluna] = round(Valor_Centro_de_Custo * data.loc[index, coluna] / data.loc[index, 'Valor original da parcela (R$)'], 2)
    return

  data = pd.read_excel(Arquivo)

  i = 0
  new_df = pd.DataFrame(columns=data.columns)

  #Loop trough all the lines
  for index in data.index:
    #Loop trough all the columns
    for column in data.columns:
      #Check if thats a center of cost
      if 'Valor no Centro de Custo' in column and pd.notna(data.loc[index, column]):
        Valor_Centro_de_Custo = data.loc[index, column]

        row = pd.DataFrame(columns=data.columns)
        row.loc[i] = data.iloc[index, :26]
        row.loc[i, 'Valor no Centro de Custo 1'] = data.loc[index, column]
        row.loc[i, 'Centro de Custo 1'] = data.iloc[index, data.columns.get_loc(column) - 1]

        Ajuste = ['Valor original da parcela (R$)', 'Valor original da parcela (R$)', 'Valor pago da parcela (R$)', 'Juros realizado (R$)',
          'Multa realizado (R$)', 'Juros previsto (R$)', 'Desconto realizado (R$)', 'Valor total pago da parcela (R$)',
          'Valor da parcela em aberto (R$)', 'Multa previsto (R$)', 'Desconto previsto (R$)', 'Valor total da parcela em aberto (R$)',
          'Valor na Categoria 1']

        for a in Ajuste:
          valor_corrigido(a)

        new_df = pd.concat([new_df, row])
        i += 1

  new_df.to_excel(f'Tratado_{Arquivo}.xlsx', index = False)
  files.download(f'Tratado_{Arquivo}.xlsx')
  return

#Loop trough all the selected files
for Arquivo in Arquivos:
  Tratar_dados(Arquivo)
# Out:
#      <input type="file" id="files-3b48e632-e727-4def-8bb2-8752d402be64" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b48e632-e727-4def-8bb2-8752d402be64">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
